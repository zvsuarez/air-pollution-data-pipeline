# %%
import pandas as pd

# %%
df = pd.read_csv('worldcities.csv').convert_dtypes()
df.head()
# Out:
#         city city_ascii      lat       lng    country iso2 iso3   admin_name
# 0      Tokyo      Tokyo  35.6897  139.6922      Japan   JP  JPN        Tōkyō  \
# 1    Jakarta    Jakarta   -6.175  106.8275  Indonesia   ID  IDN      Jakarta
# 2      Delhi      Delhi    28.61     77.23      India   IN  IND        Delhi
# 3  Guangzhou  Guangzhou    23.13    113.26      China   CN  CHN    Guangdong
# 4     Mumbai     Mumbai  19.0761   72.8775      India   IN  IND  Mahārāshtra
#
#    capital  population          id
# 0  primary    37732000  1392685764
# 1  primary    33756000  1360771077
# 2    admin    32226000  1356872604
# 3    admin    26940000  1156237133
# 4    admin    24973000  1356226629

# %%
city = df[['city_ascii', 'country','lat', 'lng', 'population']]
city.loc[:, 'country'] = city['country'].replace('Congo (Kinshasa)', 'Congo')
city = city.drop_duplicates('country', keep='first').sort_values('population', ascending=False)[:60].reset_index(drop=bool)
#city.to_csv('coordinates.csv')

# %%
city.head()
# Out:
#   city_ascii      country      lat       lng  population
# 0      Tokyo        Japan  35.6897  139.6922    37732000
# 1    Jakarta    Indonesia   -6.175  106.8275    33756000
# 2      Delhi        India    28.61     77.23    32226000
# 3  Guangzhou        China    23.13    113.26    26940000
# 4     Manila  Philippines  14.5958  120.9772    24922000
